# %%
import pandas as pd 

df = pd.read_table(r'C:\Users\Francesca\Desktop\D5 - CPI from Eurostat (clean and drop).tsv', sep='\t', header=0)
df
# Out:
#    freq,unit,geo\TIME_PERIOD  2015   2016   2017   2018   2019   2020   2021
# 0                    A,NR,AL     36     39     38     36     35     36     35
# 1                    A,NR,AT     76     75     75     76     77     76     74
# 2                    A,NR,BE     77     77     75     75     75     76     73
# 3                    A,NR,BG     41     41     43     42     43     44     42
# 4                    A,NR,CH     86     86     85     85     85     85     84
# 5                    A,NR,CY     61     55     57     59     58     57     53
# 6                    A,NR,CZ     56     55     57     59     56     54     54
# 7                    A,NR,DE     81     81     81     80     80     80     80
# 8                    A,NR,DK     91     90     88     88     87     88     88
# 9                    A,NR,EE     70     70     71     73     74     75     74
# 10                   A,NR,EL     46     44     48     45     48     50     49
# ...

# %%
to_sep = pd.DataFrame(df.iloc[:,0])
to_sep
# Out:
#    freq,unit,geo\TIME_PERIOD
# 0                    A,NR,AL
# 1                    A,NR,AT
# 2                    A,NR,BE
# 3                    A,NR,BG
# 4                    A,NR,CH
# 5                    A,NR,CY
# 6                    A,NR,CZ
# 7                    A,NR,DE
# 8                    A,NR,DK
# 9                    A,NR,EE
# 10                   A,NR,EL
# 11                   A,NR,ES
# 12                   A,NR,FI
# 13                   A,NR,FR
# 14                   A,NR,HR
# 15                   A,NR,HU
# 16                   A,NR,IE
# 17                   A,NR,IS
# 18                   A,NR,IT
# 19                   A,NR,JP
# 20                   A,NR,KR
# 21                   A,NR,LT
# 22                   A,NR,LU
# 23                   A,NR,LV
# 24                   A,NR,ME
# 25                   A,NR,MK
# 26                   A,NR,MT
# 27                   A,NR,NL
# 28                   A,NR,NO
# 29                   A,NR,PL
# 30                   A,NR,PT
# ...

# %%
to_sep[['freq', 'unit','geo']] = to_sep["freq,unit,geo\TIME_PERIOD"].str.split(",", expand = True)
to_sep
# Out:
#    freq,unit,geo\TIME_PERIOD freq unit geo
# 0                    A,NR,AL    A   NR  AL
# 1                    A,NR,AT    A   NR  AT
# 2                    A,NR,BE    A   NR  BE
# 3                    A,NR,BG    A   NR  BG
# 4                    A,NR,CH    A   NR  CH
# 5                    A,NR,CY    A   NR  CY
# 6                    A,NR,CZ    A   NR  CZ
# 7                    A,NR,DE    A   NR  DE
# 8                    A,NR,DK    A   NR  DK
# 9                    A,NR,EE    A   NR  EE
# 10                   A,NR,EL    A   NR  EL
# 11                   A,NR,ES    A   NR  ES
# 12                   A,NR,FI    A   NR  FI
# 13                   A,NR,FR    A   NR  FR
# 14                   A,NR,HR    A   NR  HR
# 15                   A,NR,HU    A   NR  HU
# 16                   A,NR,IE    A   NR  IE
# 17                   A,NR,IS    A   NR  IS
# 18                   A,NR,IT    A   NR  IT
# 19                   A,NR,JP    A   NR  JP
# 20                   A,NR,KR    A   NR  KR
# ...

# %%
df = to_sep.merge(df, left_index=True, right_index=True)
df = df.drop(columns=["freq,unit,geo\TIME_PERIOD_x", "freq,unit,geo\TIME_PERIOD_y"])
df
# Out:
#    freq unit geo  2015   2016   2017   2018   2019   2020   2021
# 0     A   NR  AL     36     39     38     36     35     36     35
# 1     A   NR  AT     76     75     75     76     77     76     74
# 2     A   NR  BE     77     77     75     75     75     76     73
# 3     A   NR  BG     41     41     43     42     43     44     42
# 4     A   NR  CH     86     86     85     85     85     85     84
# 5     A   NR  CY     61     55     57     59     58     57     53
# 6     A   NR  CZ     56     55     57     59     56     54     54
# 7     A   NR  DE     81     81     81     80     80     80     80
# 8     A   NR  DK     91     90     88     88     87     88     88
# 9     A   NR  EE     70     70     71     73     74     75     74
# 10    A   NR  EL     46     44     48     45     48     50     49
# 11    A   NR  ES     58     58     57     58     62     62     61
# 12    A   NR  FI     90     89     85     85     86     85     88
# ...

# %%
cleandf = df.drop(columns=['freq'])

cleandf
# Out:
#    unit geo  2015   2016   2017   2018   2019   2020   2021
# 0    NR  AL     36     39     38     36     35     36     35
# 1    NR  AT     76     75     75     76     77     76     74
# 2    NR  BE     77     77     75     75     75     76     73
# 3    NR  BG     41     41     43     42     43     44     42
# 4    NR  CH     86     86     85     85     85     85     84
# 5    NR  CY     61     55     57     59     58     57     53
# 6    NR  CZ     56     55     57     59     56     54     54
# 7    NR  DE     81     81     81     80     80     80     80
# 8    NR  DK     91     90     88     88     87     88     88
# 9    NR  EE     70     70     71     73     74     75     74
# 10   NR  EL     46     44     48     45     48     50     49
# 11   NR  ES     58     58     57     58     62     62     61
# 12   NR  FI     90     89     85     85     86     85     88
# 13   NR  FR     70     69     70     72     69     69     71
# ...

# %%
cleandf.to_csv(r'C:\Users\Francesca\Desktop\cleandf2.tsv')
